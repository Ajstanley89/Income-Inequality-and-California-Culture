# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
# define path to csv file
file_path = 'income-inequality-.csv'

# read csv intp pandas df
df = pd.read_csv(file_path)
df.head()
# Out:
#    ind_id                                     ind_definition reportyear  \
# 0     556  Income inequality: Gini coefficient describing...  2005-2007
# 1     556  Income inequality: Gini coefficient describing...  2006-2010
# 2     556  Income inequality: Gini coefficient describing...  2008-2010
# 3     556  Income inequality: Gini coefficient describing...  2005-2007
# 4     556  Income inequality: Gini coefficient describing...  2005-2007
#
#    race_eth_code race_eth_name geotype  geotypevalue     geoname county_name  \
# 0              9         Total      CA             6  California         NaN
# 1              9         Total      CA             6  California         NaN
# 2              9         Total      CA             6  California         NaN
# 3              9         Total      CO          6001     Alameda     Alameda
# 4              9         Total      CO          6003      Alpine      Alpine
#
#    county_fips           ...           Gini_index   LL_95CI   UL_95CI  \
# 0          NaN           ...                0.468  0.465617  0.470383
# 1          NaN           ...                0.469  0.467809  0.470191
# 2          NaN           ...                0.471  0.468617  0.473383
# 3       6001.0           ...                0.455  0.449043  0.460957
# 4       6003.0           ...                  NaN       NaN       NaN
#
#          se       rse  CA_decile     CA_RR  Median_HH_income  \
# 0  0.001216  0.259787        NaN       NaN               NaN
# 1  0.000608  0.129617        NaN       NaN               NaN
# 2  0.001216  0.258133        NaN       NaN               NaN
# 3  0.003040  0.668025        NaN  0.972222           66430.0
# 4       NaN       NaN        NaN       NaN               NaN
#
#    Median_HH_decile                 version
# 0               NaN  03/26/2014 12:00:00 AM
# 1               NaN  03/26/2014 12:00:00 AM
# 2               NaN  03/26/2014 12:00:00 AM
# 3               3.0  03/26/2014 12:00:00 AM
# 4               NaN  03/26/2014 12:00:00 AM
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#        ind_id  race_eth_code  geotypevalue  county_fips  region_code  \
# count  4788.0         4788.0   4788.000000  4743.000000  4785.000000
# mean    556.0            9.0  40680.393484  6057.977862     7.930408
# std       0.0            0.0  25836.291577    31.050892     4.564702
# min     556.0            9.0      1.000000  6001.000000     1.000000
# 25%     556.0            9.0  17480.500000  6035.000000     4.000000
# 50%     556.0            9.0  40382.000000  6059.000000     8.000000
# 75%     556.0            9.0  60609.500000  6083.000000    12.000000
# max     556.0            9.0  87090.000000  6115.000000    14.000000
#
#        Number_Households   Gini_index      LL_95CI      UL_95CI           se  \
# count       4.788000e+03  2345.000000  2345.000000  2345.000000  2345.000000
# mean        3.108647e+04     0.403342     0.344789     0.462682     0.033734
# std         3.704397e+05     0.075310     0.101299     0.087781     0.178356
# min         0.000000e+00     0.004000     0.000000     0.007574     0.000608
# 25%         2.647500e+02     0.375000     0.314064     0.418596     0.010942
# 50%         1.253500e+03     0.410000     0.369596     0.452000     0.018845
# 75%         6.668750e+03     0.443000     0.405851     0.495660     0.039514
# max         1.257750e+07     0.775000     0.599851     1.000000     8.544073
#
#                rse    CA_decile        CA_RR  Median_HH_income  \
# count  2345.000000  2140.000000  2342.000000       1967.000000
# mean     11.056622     5.498598     0.859480      63383.262328
# std     121.118065     2.872464     0.160489      26992.619504
# min       0.129617     1.000000     0.008529      13588.000000
# 25%       2.643055     3.000000     0.797656      45191.500000
# 50%       4.526935     5.000000     0.874066      57240.000000
# 75%      10.318185     8.000000     0.944563      75753.000000
# max    5852.104759    10.000000     1.652452     223611.000000
#
#        Median_HH_decile
# count       1967.000000
# mean           5.496187
# std            2.864499
# min            1.000000
# 25%            3.000000
# 50%            6.000000
# 75%            8.000000
# max           10.000000

# %%
# drop rows where gini index or median household income is na
df = df.dropna(subset=['Gini_index', 'Median_HH_income'])
df.describe()
# Out:
#        ind_id  race_eth_code  geotypevalue  county_fips  region_code  \
# count  1967.0         1967.0   1967.000000  1967.000000  1967.000000
# mean    556.0            9.0  40210.172852  6057.173869     8.791561
# std       0.0            0.0  26203.920773    29.458529     4.941290
# min     556.0            9.0    135.000000  6001.000000     1.000000
# 25%     556.0            9.0  15522.000000  6037.000000     4.000000
# 50%     556.0            9.0  40354.000000  6059.000000    10.000000
# 75%     556.0            9.0  61068.000000  6079.000000    14.000000
# max     556.0            9.0  87090.000000  6115.000000    14.000000
#
#        Number_Households   Gini_index      LL_95CI      UL_95CI           se  \
# count       1.967000e+03  1967.000000  1967.000000  1967.000000  1967.000000
# mean        3.565121e+04     0.415964     0.372627     0.459301     0.022111
# std         1.609551e+05     0.051717     0.060967     0.062142     0.017034
# min         6.700000e+01     0.112000     0.048851     0.175149     0.001216
# 25%         1.703500e+03     0.386000     0.340117     0.420074     0.010334
# 50%         8.838000e+03     0.413000     0.377319     0.449319     0.016413
# 75%         2.311700e+04     0.444000     0.410245     0.487149     0.028571
# max         3.241204e+06     0.682000     0.577532     0.935213     0.156231
#
#                rse    CA_decile        CA_RR  Median_HH_income  \
# count  1967.000000  1807.000000  1967.000000       1967.000000
# mean      5.429507     5.170448     0.886523      63383.262328
# std       4.230913     2.675667     0.110191      26992.619504
# min       0.247618     1.000000     0.238806      13588.000000
# 25%       2.541930     3.000000     0.823028      45191.500000
# 50%       3.993522     5.000000     0.880597      57240.000000
# 75%       6.956782     7.000000     0.946638      75753.000000
# max      28.766826    10.000000     1.454158     223611.000000
#
#        Median_HH_decile
# count       1967.000000
# mean           5.496187
# std            2.864499
# min            1.000000
# 25%            3.000000
# 50%            6.000000
# 75%            8.000000
# max           10.000000

# %%
# let's visually explore the data
# create figure and axes objects for the subplots. These are graphed in a 2 x 2 grid
fig = plt.figure(figsize=(20,16))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

# make the top row box plots for gini and median incomes. This will visualize outliers
df.plot(kind = 'box', y='Gini_index', ax=ax1)
df.plot(kind='box', y='Median_HH_income', ax=ax2)

# Use the bottom row for scatter plots showing relationships between variables
df.plot(kind='scatter', x='Median_HH_income', y='Gini_index', ax=ax3, alpha=0.3)
ax3.set_title('Gini Index vs Median Household Income')

df.plot(kind='scatter', x='Number_Households', y='Gini_index', ax=ax4, alpha=0.3)
ax4.set_title('Gini Index vs Number of Households')
# Out:
# Text(0.5, 1.0, 'Gini Index vs Number of Households')

# %%
df.plot(kind='hist', y='Median_HH_income', x='reportyear')
